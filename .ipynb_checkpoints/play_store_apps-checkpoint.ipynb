# %% [markdown]
# ### INTEGRANTES
#
#
# - Miguel Roberto Narvaez
# - Juan José Yanza

# %%
from bs4 import BeautifulSoup
from selenium import webdriver 
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://play.google.com/store/apps")
response = driver.execute_script("return document.documentElement.outerHTML")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Get LATEST driver version for 90.0.4430
# Trying to download new driver from https://chromedriver.storage.googleapis.com/90.0.4430.24/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\JuanJ\.wdm\drivers\chromedriver\win32\90.0.4430.24]

# %%
soup = BeautifulSoup(response, 'html.parser')
apps = soup.find_all("div",class_="WsMG1c nnK0zc")
name_app = []
links = []

div_link_app = soup.find_all("div",class_="vU6FJ p63iDd")

for app in apps:
    name_app.append(app.text)

for div in div_link_app:
    a = div.find('a', href = True)
    if a is not None:
        links.append("https://play.google.com"+a['href'])

# %%
links
# Out:
# ['https://play.google.com/store/apps/details?id=com.facebook.katana',
#  'https://play.google.com/store/apps/details?id=com.zhiliaoapp.musically',
#  'https://play.google.com/store/apps/details?id=com.facebook.orca',
#  'https://play.google.com/store/apps/details?id=com.facebook.lite',
#  'https://play.google.com/store/apps/details?id=com.instagram.android',
#  'https://play.google.com/store/apps/details?id=com.google.android.apps.meetings',
#  'https://play.google.com/store/apps/details?id=com.wildspike.wormszone',
#  'https://play.google.com/store/apps/details?id=com.google.android.play.games',
#  'https://play.google.com/store/apps/details?id=com.google.android.apps.translate',
#  'https://play.google.com/store/apps/details?id=com.outfit7.mytalkingangelafree',
#  'https://play.google.com/store/apps/details?id=com.adobe.reader',
#  'https://play.google.com/store/apps/details?id=com.zhiliaoapp.musically.go',
#  'https://play.google.com/store/apps/details?id=net.daylio',
#  'https://play.google.com/store/apps/details?id=vsin.t16_funny_photo',
#  'https://play.google.com/store/apps/details?id=com.endel.endel',
#  'https://play.google.com/store/apps/details?id=net.metapps.sleepsounds',
#  'https://play.google.com/store/apps/details?id=fm.player',
#  'https://play.google.com/store/apps/details?id=at.funmusic.sepp.mobile',
#  'https://play.google.com/store/apps/details?id=com.instagram.android',
#  'https://play.google.com/store/apps/details?id=com.dywx.larkplayer',
#  'https://play.google.com/store/apps/details?id=com.microsoft.office.word',
#  'https://play.google.com/store/apps/details?id=com.facebook.mlite',
#  'https://play.google.com/store/apps/details?id=com.outfit7.talkingtomgoldrun',
#  'https://play.google.com/store/apps/details?id=com.kwai.video',
#  'https://play.google.com/store/apps/details?id=com.outfit7.mytalkingtomfriends',
#  'https://play.google.com/store/apps/details?id=videoeditor.videorecorder.screenrecorder',
#  'https://play.google.com/store/apps/details?id=com.superbinogo.jungleboyadventure',
#  'https://play.google.com/store/apps/details?id=com.zhiliaoapp.musically.go',
#  'https://play.google.com/store/apps/details?id=com.vicman.photolabpro',
#  'https://play.google.com/store/apps/details?id=com.tocaboca.tocaoffice',
#  'https://play.google.com/store/apps/details?id=com.tocaboca.tocaafterschool',
#  'https://play.google.com/store/apps/details?id=com.duolingo',
#  'https://play.google.com/store/apps/details?id=com.camerasideas.instashot',
#  'https://play.google.com/store/apps/details?id=com.netflix.mediaclient',
#  'https://play.google.com/store/apps/details?id=video.like.lite',
#  'https://play.google.com/store/apps/details?id=org.telegram.messenger',
#  'https://play.google.com/store/apps/details?id=com.mercadolibre',
#  'https://play.google.com/store/apps/details?id=com.truecaller',
#  'https://play.google.com/store/apps/details?id=com.memrise.android.memrisecompanion',
#  'https://play.google.com/store/apps/details?id=com.facebook.lite',
#  'https://play.google.com/store/apps/details?id=com.facebook.mlite',
#  'https://play.google.com/store/apps/details?id=com.google.android.apps.translate',
#  'https://play.google.com/store/apps/details?id=cn.xender',
#  'https://play.google.com/store/apps/details?id=videoeditor.videorecorder.screenrecorder',
#  'https://play.google.com/store/apps/details?id=com.teacapps.barcodescanner',
#  'https://play.google.com/store/apps/details?id=org.mozilla.firefox',
#  'https://play.google.com/store/apps/details?id=com.waze',
#  'https://play.google.com/store/apps/details?id=com.truecaller',
#  'https://play.google.com/store/apps/details?id=com.gamma.scan',
#  'https://play.google.com/store/apps/details?id=com.google.android.apps.adm',
#  'https://play.google.com/store/apps/details?id=com.google.android.apps.kids.familylink',
#  'https://play.google.com/store/apps/details?id=com.spotify.music',
#  'https://play.google.com/store/apps/details?id=com.shazam.android',
#  'https://play.google.com/store/apps/details?id=com.soundcloud.android',
#  'https://play.google.com/store/apps/details?id=video.like',
#  'https://play.google.com/store/apps/details?id=com.kwai.video',
#  'https://play.google.com/store/apps/details?id=com.lemon.lvoverseas',
#  'https://play.google.com/store/apps/details?id=com.rsupport.mvagent',
#  'https://play.google.com/store/apps/details?id=com.google.android.play.games',
#  'https://play.google.com/store/apps/details?id=com.amazon.avod.thirdpartyclient',
#  'https://play.google.com/store/apps/details?id=wp.wattpad',
#  'https://play.google.com/store/apps/details?id=com.waze',
#  'https://play.google.com/store/apps/details?id=com.ubercab',
#  'https://play.google.com/store/apps/details?id=com.google.android.apps.adm']

# %%
apps_data = pd.DataFrame()

# %%
apps_data['app'] = name_app

# %%
apps_data['link'] = links

# %%
apps_data
# Out:
#                                                 app  \
# 0                                          Facebook
# 1                                            TikTok
# 2        Messenger: mensajes y videollamadas gratis
# 3                                     Facebook Lite
# 4                                         Instagram
# ..                                              ...
# 59                               Amazon Prime Video
# 60             Wattpad – Donde las historias viven.
# 61  Waze - GPS, Mapas, Alertas y Navegación en Vivo
# 62                             Uber - Pide un viaje
# 63               Encontrar mi dispositivo de Google
#
#                                                  link
# 0   https://play.google.com/store/apps/details?id=...
# 1   https://play.google.com/store/apps/details?id=...
# 2   https://play.google.com/store/apps/details?id=...
# 3   https://play.google.com/store/apps/details?id=...
# 4   https://play.google.com/store/apps/details?id=...
# ..                                                ...
# 59  https://play.google.com/store/apps/details?id=...
# 60  https://play.google.com/store/apps/details?id=...
# 61  https://play.google.com/store/apps/details?id=...
# 62  https://play.google.com/store/apps/details?id=...
# 63  https://play.google.com/store/apps/details?id=...
#
# [64 rows x 2 columns]

# %%
rated = []
valorations = []
genders= []

for a in links:
    driver.get(a)
    response = driver.execute_script("return document.documentElement.outerHTML")
    soup = BeautifulSoup(response, 'html.parser')
    rate = soup.find_all("div",class_="BHMmbe")
    valoration = soup.find('span', {'class' : 'AYi5wd TBRnV'}).get_text()
    gender = soup.find_all('a', {'class' : 'hrTbp R8zArc'})[-1].get_text()
    
    
    
    for rt in rate:
        rt_nuevo = rt.text.replace(',', '.')
        rated.append(float(rt_nuevo))
        
    
    
    valorations.append(int(valoration.replace(',', '')))
    genders.append(gender)

# %%
genders
# Out:
# ['Social',
#  'Social',
#  'Comunicación',
#  'Social',
#  'Social',
#  'Negocios',
#  'Acción',
#  'Entretenimiento',
#  'Herramientas',
#  'Juegos ocasionales',
#  'Productividad',
#  'Social',
#  'Estilo de vida',
#  'Fotografía',
#  'Salud y bienestar',
#  'Salud y bienestar',
#  'Música y audio',
#  'Educación',
#  'Social',
#  'Música y audio',
#  'Productividad',
#  'Comunicación',
#  'Acción',
#  'Aplicaciones de video',
#  'Juegos ocasionales',
#  'Aplicaciones de video',
#  'Aventura',
#  'Social',
#  'Fotografía',
#  'Juegos simbólicos',
#  'Juegos simbólicos',
#  'Educación',
#  'Fotografía',
#  'Entretenimiento',
#  'Social',
#  'Comunicación',
#  'Compras',
#  'Comunicación',
#  'Educación',
#  'Social',
#  'Comunicación',
#  'Herramientas',
#  'Herramientas',
#  'Aplicaciones de video',
#  'Productividad',
#  'Comunicación',
#  'Mapas y navegación',
#  'Comunicación',
#  'Herramientas',
#  'Herramientas',
#  'Herramientas',
#  'Música y audio',
#  'Música y audio',
#  'Música y audio',
#  'Aplicaciones de video',
#  'Aplicaciones de video',
#  'Aplicaciones de video',
#  'Productividad',
#  'Entretenimiento',
#  'Entretenimiento',
#  'Libros y referencias',
#  'Mapas y navegación',
#  'Mapas y navegación',
#  'Herramientas']

# %%
rated
# Out:
# [2.9,
#  4.4,
#  4.1,
#  3.6,
#  3.8,
#  3.8,
#  4.3,
#  4.3,
#  4.5,
#  4.2,
#  4.6,
#  3.9,
#  4.6,
#  4.4,
#  4.4,
#  4.6,
#  4.6,
#  4.5,
#  3.8,
#  4.7,
#  4.4,
#  4.0,
#  4.4,
#  4.4,
#  4.3,
#  4.7,
#  4.1,
#  3.9,
#  4.7,
#  4.4,
#  4.2,
#  4.6,
#  4.8,
#  4.4,
#  4.3,
#  4.3,
#  4.8,
#  4.5,
#  4.6,
#  3.6,
#  4.0,
#  4.5,
#  4.5,
#  4.7,
#  4.6,
#  4.4,
#  4.1,
#  4.5,
#  4.7,
#  4.4,
#  2.9,
#  4.4,
#  4.4,
#  4.6,
#  4.3,
#  4.4,
#  4.5,
#  4.3,
#  4.3,
#  4.3,
#  4.0,
#  4.1,
#  4.4,
#  4.4]

# %%
apps_data['rated'] = rated
apps_data['valorations'] = valorations
apps_data['gender'] = genders

# %%
apps_data
# Out:
#                                                 app  \
# 0                                          Facebook
# 1                                            TikTok
# 2        Messenger: mensajes y videollamadas gratis
# 3                                     Facebook Lite
# 4                                         Instagram
# ..                                              ...
# 59                               Amazon Prime Video
# 60             Wattpad – Donde las historias viven.
# 61  Waze - GPS, Mapas, Alertas y Navegación en Vivo
# 62                             Uber - Pide un viaje
# 63               Encontrar mi dispositivo de Google
#
#                                                  link  rated  valorations  \
# 0   https://play.google.com/store/apps/details?id=...    2.9    114221570
# 1   https://play.google.com/store/apps/details?id=...    4.4     35095786
# 2   https://play.google.com/store/apps/details?id=...    4.1     78073374
# 3   https://play.google.com/store/apps/details?id=...    3.6     18018991
# 4   https://play.google.com/store/apps/details?id=...    3.8    118941634
# ..                                                ...    ...          ...
# 59  https://play.google.com/store/apps/details?id=...    4.3      2684414
# 60  https://play.google.com/store/apps/details?id=...    4.0      4192802
# 61  https://play.google.com/store/apps/details?id=...    4.1      8262792
# 62  https://play.google.com/store/apps/details?id=...    4.4      8534672
# 63  https://play.google.com/store/apps/details?id=...    4.4       932753
#
#                   gender
# 0                 Social
# 1                 Social
# 2           Comunicación
# 3                 Social
# 4                 Social
# ..                   ...
# 59       Entretenimiento
# 60  Libros y referencias
# 61    Mapas y navegación
# 62    Mapas y navegación
# 63          Herramientas
#
# [64 rows x 5 columns]

# %%
'''
0: Last update date
1: Size MB-GB
2: Installs
3: Current version
4: Requires Android
5: Supported Version
6: Classification
7: App elements
8: Integrated app elements price
9: Permissions /x
10: Report x/
11: Company

'''
driver1 = webdriver.Chrome(ChromeDriverManager().install())


'''

driver1.get("https://play.google.com/store/apps/details?id=com.facebook.katana")
others = driver1.find_elements_by_class_name("htlgb")
for x in range (len(others)):
     if x % 2 == 0:
            list_others.append(others[x].text)
print(list_others)
list_others[10]
'''
list_others = []
lista = []

for a in links:
    driver1.get(a)
    others = driver1.find_elements_by_class_name("htlgb")
    list_aux = []
    
    for x in range (len(others)):
        if x % 2 == 0:
            list_aux.append(others[x].text)
    lista.append(list_aux)
print(lista)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\JuanJ\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# [['18 de mayo de 2021', 'Varía con el dispositivo.', '5,000,000,000+', 'Varía con el dispositivo.', 'Varía con el dispositivo.', 'Adolescentes\nMás información', 'Los usuarios interactúan, Comparte información., Comparte la ubicación., Compras digitales', '$0,99-$99,99 por elemento', 'Ver detalles', 'Marcar como inadecuado', 'Facebook', 'Visitar el sitio web\nfacebook.android@fb.com\nPolítica de Privacidad\n1 Hacker Way Menlo Park, CA 94025'], ['17 de mayo de 2021', '93M', '1,000,000,000+', '19.5.4', '4.4 y versiones posteriores', 'Adolescentes\nMás información', 'Los usuarios interactúan, Comparte la ubicación., Compras en la app', '$0,99 por elemento', 'Ver detalles', 'Marcar como inadecuado', 'TikTok Pte. Ltd.', 'Visitar el sitio web\nfeedback@tiktok.com\nPolítica de Privacidad\n201 Henderson Road, #06-22 Apex@Henderson, Singapore 159545 Singapore'], ['17 de mayo de 2021', 'Varía con el dispositivo.', '5,000,000,000+', '311.0.0.13.119', 'Varía con el dispositivo.', 'Todos\nMás información', 'Los usuarios interactúan, Comparte la ubicación., Compras en la app', 'Ver detalles', 'Marcar como inadecuado', 'Facebook', 'Visitar el sitio web\nandroid-support@fb.com\nPolítica de Privacidad\n1 Hacker Way Menlo Park, CA 94025'], ['18 de mayo de 2021', 'Varía con el dispositivo.', '1,000,000,000+', 'Varía con el dispositivo.', 'Varía con el dispositivo.', 'Adolescentes\nMás información', 'Los usuarios interactúan, Comparte información., Comparte la ubicación.', 'Ver detalles', 'Marcar como inadecuado', 'Facebook', 'Visitar el sitio web\nlite-android-support@fb.com\nPolítica de Privacidad\n1 Hacker Way Menlo Park, CA 94025'], ['17 de mayo de 2021', 'Varía con el dispositivo.', '1,000,000,000+', 'Varía con el dispositivo.', 'Varía con el dispositivo.', 'Adolescentes\nMás información', 'Los usuarios interactúan, Comparte información., Comparte la ubicación.', '$0,99-$4,99 por elemento', 'Ver detalles', 'Marcar como inadecuado', 'Instagram', 'Visitar el sitio web\nandroid-support@instagram.com\nPolítica de Privacidad\nFacebook, Inc. 1601 Willow Rd Menlo Park, CA 94025 United States'], ['13 de mayo de 2021', 'Varía con el dispositivo.', '100,000,000+', 'Varía con el dispositivo.', 'Varía con el dispositivo.', 'Todos\nMás información', 'Los usuarios interactúan', 'Ver detalles', 'Marcar como inadecuado', 'Google LLC', 'Visitar el sitio web\napps-help@google.com\nPolítica de Privacidad\n1600 Amphitheatre Parkway, Mountain View 94043'], ['16 de mayo de 2021', '42M', '100,000,000+', '2.0.0', '5.1 y versiones posteriores', 'Todos\nMás información', 'Compras digitales', '$0,99-$4,99 por elemento', 'Ver detalles', 'Marcar como inadecuado', 'CASUAL AZUR GAMES', 'Visitar el sitio web\nsupport@wildspike.com\nPolítica de Privacidad\n30929, Thuraya 1 Building, Premises 1009, Floor 10, Dubai'], ['26 de abril de 2021', 'Varía con el dispositivo.', '1,000,000,000+', 'Varía con el dispositivo.', 'Varía con el dispositivo.', 'Adolescentes\nContenido diverso: Se aconseja discreción\nMás información', 'Los usuarios interactúan, Compras digitales', 'Ver detalles', 'Marcar como inadecuado', 'Google LLC', 'Visitar el sitio web\ngoogleplay-support@google.com\nPolítica de Privacidad\n1600 Amphitheatre Parkway, Mountain View 94043'], ['18 de marzo de 2021', 'Varía con el dispositivo.', '1,000,000,000+', 'Varía con el dispositivo.', 'Varía con el dispositivo.', 'Todos\nMás información', 'Ver detalles', 'Marcar como inadecuado', 'Google LLC', 'Visitar el sitio web\ntranslate-mobile-support@google.com\nPolítica de Privacidad\n1600 Amphitheatre Parkway, Mountain View 94043'], ['4 de mayo de 2021', '115M', '500,000,000+', '5.2.1.1515', '5.0 y versiones posteriores', 'Todos\nMás información', 'Los usuarios interactúan, Compras digitales', '$0,99-$99,99 por elemento', 'Ver detalles', 'Marcar como inadecuado', 'Outfit7 Limited', 'Visitar el sitio web\nsupport@outfit7.com\nPolítica de Privacidad\nOutfit7 Limited Christaki Kranou 20, 2nd Floor 4041 Limassol Cyprus'], ['6 de ...

# %%
last_update = []
size = []
installs = []
current_version_app = []
android_version_req = []
classification = []

for a in lista:
    aux_last_update = a[0]
    aux_size = a[1]
    aux_installs = a[2]
    aux_current_version_app = a[3]
    aux_android_version_req = a[4]
    aux_classification = a[5]
    aux_company = a[8]
    
    last_update.append(a[0].strip("\n"))

    # Transformando variable size 
    if a[1] == 'Varía con el dispositivo.':
        aux_size = '0'
    if 'M' in a[1]:
        aux_size = a[1].strip('M')

    size.append(float(aux_size))
    
    # Transformando variable installs
    aux_installs = aux_installs.strip('+').replace(",", "")
    installs.append(int(aux_installs))

    # Transformando variable current_version_app
    aux_current_version_app = aux_current_version_app.strip('\n')
    current_version_app.append(aux_current_version_app)
    
    # Transformando variable android_version_req
    aux_android_version_req = aux_android_version_req.strip('\n')
    aux_android_version_req = aux_android_version_req.strip(' y versiones posteriores')
    android_version_req.append(aux_android_version_req)
    
    # Transformando variable classification
    
    aux_classification_lista = aux_classification.split('\n')
    classification.append(aux_classification_lista[0])

# %%
apps_data['last_update'] = last_update
apps_data['size'] = size
apps_data['installs'] = installs
apps_data['current_version_app'] = current_version_app
apps_data['android_version_req'] = android_version_req
apps_data['classification'] = classification

# %%
apps_data
# Out:
#                                                 app  \
# 0                                          Facebook
# 1                                            TikTok
# 2        Messenger: mensajes y videollamadas gratis
# 3                                     Facebook Lite
# 4                                         Instagram
# ..                                              ...
# 59                               Amazon Prime Video
# 60             Wattpad – Donde las historias viven.
# 61  Waze - GPS, Mapas, Alertas y Navegación en Vivo
# 62                             Uber - Pide un viaje
# 63               Encontrar mi dispositivo de Google
#
#                                                  link  rated  valorations  \
# 0   https://play.google.com/store/apps/details?id=...    2.9    114221570
# 1   https://play.google.com/store/apps/details?id=...    4.4     35095786
# 2   https://play.google.com/store/apps/details?id=...    4.1     78073374
# 3   https://play.google.com/store/apps/details?id=...    3.6     18018991
# 4   https://play.google.com/store/apps/details?id=...    3.8    118941634
# ..                                                ...    ...          ...
# 59  https://play.google.com/store/apps/details?id=...    4.3      2684414
# 60  https://play.google.com/store/apps/details?id=...    4.0      4192802
# 61  https://play.google.com/store/apps/details?id=...    4.1      8262792
# 62  https://play.google.com/store/apps/details?id=...    4.4      8534672
# 63  https://play.google.com/store/apps/details?id=...    4.4       932753
#
#                   gender            last_update  size    installs  \
# 0                 Social     18 de mayo de 2021   0.0  5000000000
# 1                 Social     17 de mayo de 2021  93.0  1000000000
# 2           Comunicación     17 de mayo de 2021   0.0  5000000000
# 3                 Social     18 de mayo de 2021   0.0  1000000000
# 4                 Social     17 de mayo de 2021   0.0  1000000000
# ..                   ...                    ...   ...         ...
# 59       Entretenimiento      7 de mayo de 2021  28.0   100000000
# 60  Libros y referencias     12 de mayo de 2021   0.0   100000000
# 61    Mapas y navegación     6 de abril de 2021  87.0   100000000
# 62    Mapas y navegación     17 de mayo de 2021   0.0   500000000
# 63          Herramientas  11 de febrero de 2021   3.8   100000000
#
#           current_version_app        android_version_req classification
# 0   Varía con el dispositivo.  Varía con el dispositivo.   Adolescentes
# 1                      19.5.4                        4.4   Adolescentes
# 2              311.0.0.13.119  Varía con el dispositivo.          Todos
# 3   Varía con el dispositivo.  Varía con el dispositivo.   Adolescentes
# 4   Varía con el dispositivo.  Varía con el dispositivo.   Adolescentes
# ..                        ...                        ...            ...
# 59  Varía con el dispositivo.  Varía con el dispositivo.   Adolescentes
# 60  Varía con el dispositivo.  Varía con el dispositivo.   Adolescentes
# 61                   4.73.0.3                        4.4          Todos
# 62  Varía con el dispositivo.  Varía con el dispositivo.          Todos
# 63                    2.4.036                        4.1          Todos
#
# [64 rows x 11 columns]

# %%
apps_data.describe
# Out:
# <bound method NDFrame.describe of                                                 app  \
# 0                                          Facebook
# 1                                            TikTok
# 2        Messenger: mensajes y videollamadas gratis
# 3                                     Facebook Lite
# 4                                         Instagram
# ..                                              ...
# 59                               Amazon Prime Video
# 60             Wattpad – Donde las historias viven.
# 61  Waze - GPS, Mapas, Alertas y Navegación en Vivo
# 62                             Uber - Pide un viaje
# 63               Encontrar mi dispositivo de Google
#
#                                                  link  rated  valorations  \
# 0   https://play.google.com/store/apps/details?id=...    2.9    114221570
# 1   https://play.google.com/store/apps/details?id=...    4.4     35095786
# 2   https://play.google.com/store/apps/details?id=...    4.1     78073374
# 3   https://play.google.com/store/apps/details?id=...    3.6     18018991
# 4   https://play.google.com/store/apps/details?id=...    3.8    118941634
# ..                                                ...    ...          ...
# 59  https://play.google.com/store/apps/details?id=...    4.3      2684414
# 60  https://play.google.com/store/apps/details?id=...    4.0      4192802
# 61  https://play.google.com/store/apps/details?id=...    4.1      8262792
# 62  https://play.google.com/store/apps/details?id=...    4.4      8534672
# 63  https://play.google.com/store/apps/details?id=...    4.4       932753
#
#                   gender            last_update  size    installs  \
# 0                 Social     18 de mayo de 2021   0.0  5000000000
# 1                 Social     17 de mayo de 2021  93.0  1000000000
# 2           Comunicación     17 de mayo de 2021   0.0  5000000000
# 3                 Social     18 de mayo de 2021   0.0  1000000000
# 4                 Social     17 de mayo de 2021   0.0  1000000000
# ..                   ...                    ...   ...         ...
# 59       Entretenimiento      7 de mayo de 2021  28.0   100000000
# 60  Libros y referencias     12 de mayo de 2021   0.0   100000000
# 61    Mapas y navegación     6 de abril de 2021  87.0   100000000
# 62    Mapas y navegación     17 de mayo de 2021   0.0   500000000
# 63          Herramientas  11 de febrero de 2021   3.8   100000000
#
#           current_version_app        android_version_req classification
# 0   Varía con el dispositivo.  Varía con el dispositivo.   Adolescentes
# 1                      19.5.4                        4.4   Adolescentes
# 2              311.0.0.13.119  Varía con el dispositivo.          Todos
# 3   Varía con el dispositivo.  Varía con el dispositivo.   Adolescentes
# 4   Varía con el dispositivo.  Varía con el dispositivo.   Adolescentes
# ..                        ...                        ...            ...
# 59  Varía con el dispositivo.  Varía con el dispositivo.   Adolescentes
# 60  Varía con el dispositivo.  Varía con el dispositivo.   Adolescentes
# 61                   4.73.0.3                        4.4          Todos
# 62  Varía con el dispositivo.  Varía con el dispositivo.          Todos
# 63                    2.4.036                        4.1          Todos
#
# [64 rows x 11 columns]>

# %%
apps_data.to_csv('apps_data.csv')
